# %%
import tensorflow as tf
import pandas as pd
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Dense

df = pd.read_csv('Iris.csv')
df = df.drop(columns='Id')

category = pd.get_dummies(df.Species)
new_df = pd.concat([df, category], axis=1)
new_df = new_df.drop(columns='Species')

dataset = new_df.values

# %%
X = dataset[:,0:4]
y = dataset[:,4:7]

# %%
min_max_scaler = preprocessing.MinMaxScaler()
X_scale = min_max_scaler.fit_transform(X)
X_train, X_test, Y_train, Y_test = train_test_split(X_scale, y, test_size=0.3)

# %%
model = Sequential([
                    Dense(64, activation='relu', input_shape=(4,)),
                    Dense(64, activation='relu'),
                    Dense(3, activation='softmax'),])
model.compile(optimizer='Adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
class myCallback(tf.keras.callbacks.Callback):
  def on_epoch_end(self, epoch, logs={}):
    if(logs.get('accuracy')>0.9):
      print("\nAkurasi telah mencapai >90%!")
      self.model.stop_training = True
callbacks = myCallback()

# %%
model.fit(X_train, Y_train, epochs=50, callbacks=[callbacks])
# Out:
# Epoch 1/50
# 4/4 [==============================] - 1s 6ms/step - loss: 1.0925 - accuracy: 0.3905
# Epoch 2/50
# 4/4 [==============================] - 0s 3ms/step - loss: 1.0553 - accuracy: 0.3714
# Epoch 3/50
# 4/4 [==============================] - 0s 4ms/step - loss: 1.0213 - accuracy: 0.5905
# Epoch 4/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.9916 - accuracy: 0.6286
# Epoch 5/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.9615 - accuracy: 0.6476
# Epoch 6/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.9351 - accuracy: 0.6476
# Epoch 7/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.9073 - accuracy: 0.6476
# Epoch 8/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.8806 - accuracy: 0.6571
# Epoch 9/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.8539 - accuracy: 0.6571
# Epoch 10/50
# 4/4 [==============================] - 0s 4ms/step - loss: 0.8267 - accuracy: 0.6571
# Epoch 11/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.8000 - accuracy: 0.6571
# Epoch 12/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7718 - accuracy: 0.6571
# Epoch 13/50
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7452 - accuracy: 0.6571
# Epoch 14/50
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7197 - accuracy: 0.6571
# Epoch 15/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.6933 - accuracy: 0.6571
# Epoch 16/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.6676 - accuracy: 0.6571
# Epoch 17/50
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6416 - accuracy: 0.6571
# Epoch 18/50
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6163 - accuracy: 0.6571
# Epoch 19/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5923 - accuracy: 0.6571
# Epoch 20/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5688 - accuracy: 0.6571
# Epoch 21/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5471 - accuracy: 0.6667
# Epoch 22/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5266 - accuracy: 0.6857
# Epoch 23/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5072 - accuracy: 0.7048
# Epoch 24/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4900 - accuracy: 0.7238
# Epoch 25/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4736 - accuracy: 0.7619
# Epoch 26/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4595 - accuracy: 0.8190
# Epoch 27/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4457 - accuracy: 0.8000
# Epoch 28/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4329 - accuracy: 0.8190
# Epoch 29/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4222 - accuracy: 0.8857
# Epoch 30/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4100 - accuracy: 0.8952
# Epoch 31/50
# 1/4 [======>.......................] - ETA: 0s - loss: 0.3404 - accuracy: 1.0000
# Akurasi telah mencapai >90%!
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3997 - accuracy: 0.9143
