# %% [markdown]
# <a href="https://colab.research.google.com/github/AlgorithmBurv/PML/blob/main/PML_2_Iris.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Dense

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
path = "/content/drive/MyDrive/Dataset PML/Iris (1).csv"
load_data = pd.read_csv(path)

# %%
# Membuat data frame

df=pd.DataFrame(load_data)
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %% [markdown]
# ### menghapus kolom id

# %%
df = df.drop(columns='Id')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-9-02b09d8b5699> in <cell line: 1>()
# ----> 1 df = df.drop(columns='Id')
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5397                 weight  1.0     0.8
#    5398         """
# -> 5399         return super().drop(
#    5400             labels=labels,
#    5401             axis=axis,
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
# ...

# %% [markdown]
# ### one hot encoding kolom species

# %%
category = pd.get_dummies(df.Species)
category
# Out:
#      Iris-setosa  Iris-versicolor  Iris-virginica
# 0              1                0               0
# 1              1                0               0
# 2              1                0               0
# 3              1                0               0
# 4              1                0               0
# ..           ...              ...             ...
# 145            0                0               1
# 146            0                0               1
# 147            0                0               1
# 148            0                0               1
# 149            0                0               1
#
# [150 rows x 3 columns]

# %% [markdown]
# ### menggabungkan kolom hasil one hot encoding dan membuang kolom spesies

# %%
new_df = pd.concat([df, category], axis=1)
new_df = new_df.drop(columns='Species')
new_df
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Iris-setosa  \
# 0              5.1           3.5            1.4           0.2            1
# 1              4.9           3.0            1.4           0.2            1
# 2              4.7           3.2            1.3           0.2            1
# 3              4.6           3.1            1.5           0.2            1
# 4              5.0           3.6            1.4           0.2            1
# ..             ...           ...            ...           ...          ...
# 145            6.7           3.0            5.2           2.3            0
# 146            6.3           2.5            5.0           1.9            0
# 147            6.5           3.0            5.2           2.0            0
# 148            6.2           3.4            5.4           2.3            0
# 149            5.9           3.0            5.1           1.8            0
#
#      Iris-versicolor  Iris-virginica
# ...

# %% [markdown]
# ### konversi dataframe menjadi numpy array

# %%
dataset = new_df.values
dataset
# Out:
# array([[5.1, 3.5, 1.4, ..., 1. , 0. , 0. ],
#        [4.9, 3. , 1.4, ..., 1. , 0. , 0. ],
#        [4.7, 3.2, 1.3, ..., 1. , 0. , 0. ],
#        ...,
#        [6.5, 3. , 5.2, ..., 0. , 0. , 1. ],
#        [6.2, 3.4, 5.4, ..., 0. , 0. , 1. ],
#        [5.9, 3. , 5.1, ..., 0. , 0. , 1. ]])

# %% [markdown]
# ### memisahkan antara atribut dan label

# %%
# Pilih 4 kolom pertama untuk dijadikan sebagai atribut
X = dataset[:,0:4]
# Pilih 3 kolom terakhir sebagai label
y = dataset[:,4:7]

# %%
# Normalize
min_max_scaler = preprocessing.MinMaxScaler()
X_scale = min_max_scaler.fit_transform(X)
X_scale
# Out:
# array([[0.22222222, 0.625     , 0.06779661, 0.04166667],
#        [0.16666667, 0.41666667, 0.06779661, 0.04166667],
#        [0.11111111, 0.5       , 0.05084746, 0.04166667],
#        [0.08333333, 0.45833333, 0.08474576, 0.04166667],
#        [0.19444444, 0.66666667, 0.06779661, 0.04166667],
#        [0.30555556, 0.79166667, 0.11864407, 0.125     ],
#        [0.08333333, 0.58333333, 0.06779661, 0.08333333],
#        [0.19444444, 0.58333333, 0.08474576, 0.04166667],
#        [0.02777778, 0.375     , 0.06779661, 0.04166667],
#        [0.16666667, 0.45833333, 0.08474576, 0.        ],
#        [0.30555556, 0.70833333, 0.08474576, 0.04166667],
#        [0.13888889, 0.58333333, 0.10169492, 0.04166667],
#        [0.13888889, 0.41666667, 0.06779661, 0.        ],
#        [0.        , 0.41666667, 0.01694915, 0.        ],
#        [0.41666667, 0.83333333, 0.03389831, 0.04166667],
#        [0.38888889, 1.        , 0.08474576, 0.125     ],
# ...

# %% [markdown]
# ### pembagian data menjadi data latih dan data uji

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X_scale, y, test_size=0.3)

# %% [markdown]
# ### Untuk arsitektur model menggunakan 3 buah layer. Activation function yang digunakan pada layer terakhir dipilih softmax karena activation tersebut umum dipakai untuk klasifikasi multi kelas seperti ini.

# %%
model = Sequential([
                    Dense(64, activation='relu', input_shape=(4,)),
                    Dense(64, activation='relu'),
                    Dense(3, activation='softmax'),])

# %% [markdown]
# ### Untuk masalah klasifikasi multi kelas menggunakan loss ‘categorical_crossentropy’.

# %%
model.compile(optimizer='Adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
hist = model.fit(X_train, Y_train, epochs=100)
# Out:
# Epoch 1/100
# 4/4 [==============================] - 1s 6ms/step - loss: 1.0995 - accuracy: 0.3048
# Epoch 2/100
# 4/4 [==============================] - 0s 4ms/step - loss: 1.0630 - accuracy: 0.3238
# Epoch 3/100
# 4/4 [==============================] - 0s 4ms/step - loss: 1.0332 - accuracy: 0.3238
# Epoch 4/100
# 4/4 [==============================] - 0s 4ms/step - loss: 1.0060 - accuracy: 0.4476
# Epoch 5/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.9805 - accuracy: 0.6571
# Epoch 6/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.9546 - accuracy: 0.7429
# Epoch 7/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.9269 - accuracy: 0.7429
# Epoch 8/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.8980 - accuracy: 0.7048
# Epoch 9/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.8677 - accuracy: 0.6857
# Epoch 10/100
# ...

# %%
model.evaluate(X_test, Y_test)
# Out:
# 2/2 [==============================] - 0s 10ms/step - loss: 0.1157 - accuracy: 0.9778
# [0.11565183103084564, 0.9777777791023254]
